# %% [markdown]
# <div style="text-align: center; padding: 30px 10px;">
#
# <h2 style="font-size: 30px; margin-top: 5px;">
# Лабораторная работа 5. Requests. BeautifulSoup. API.
# </h2>
#
# <hr style="width: 60%; border: 1px solid #10069f; margin: 25px auto;">
#
# </div>
#
# Если Вы видите <b><font color="#FF69B4"> Ваш ответ здесь </font></b> - надо поменять текст внутри блока на свой текстовый ответ на вопрос.
#
#
# ВАЖНО! Здесь и далее от вас ожидается чистый код, близкий к тому, что нужно в индустрии. В контексте данной лабораторной работы ожидаются корректные названия у полей, методов и переменных, которые вы вводите; корректная инкапсуляция - нижнее подчеркивание или два перед названием метода или атрибута. Для корректной инкапсуляции можно (и даже нужно) добавлять нижние подчеркивания даже к названиям методов/атрибутов из условий задач :)

# %% [markdown]
# В маленьких деревнях, где до сих пор живут люди, зачастую нет своих магазинов, даже продуктовых (экономически нецелесообразно открывать магазин для 7-20 жителей деревни). Вместо этого к ним 1-2 раза в неделю приезжает автолавка - магазин на колёсах, который продаёт все основные продукты (хлеб, яйца, крупы, макароны, кондитерские изделия и пр.)
#
# Ваша задача в этой лабораторной работе - построить маршрут для Автолавки с учётом всех нюансов.

# %% [markdown]
# ## Часть 1. Сбор деревень. 3 балла.
#
# Возьми список деревень [Гагаринского района]( https://ru.wikipedia.org/wiki/%D0%93%D0%B0%D0%B3%D0%B0%D1%80%D0%B8%D0%BD%D1%81%D0%BA%D0%B8%D0%B9_%D1%80%D0%B0%D0%B9%D0%BE%D0%BD_(%D0%A1%D0%BC%D0%BE%D0%BB%D0%B5%D0%BD%D1%81%D0%BA%D0%B0%D1%8F_%D0%BE%D0%B1%D0%BB%D0%B0%D1%81%D1%82%D1%8C) )
#
#
# !! Если хочешь - можешь взять любой другой район, особенно, если это твой родной.
#
#
# **Ваша задача:** Согласно Вашему варианту спарсить странички википедии и получить датафрейм с населенными пунктами, где должны быть собраны следующие данные:
#
# - Название
# - Тип
# - Население
# - Площадь
# - Географические координаты
# - Муниципальное образование, к которому относится населенный пункт
# - Почтовый индекс

# %%
# TODO

# %% [markdown]
# Проанализируйте полученный набор данных. Всю ли информацию получилось собрать?

# %% [markdown]
# ## Часть 2. Визуализация датасета. 2 балла.
#
# 1. Добавьте столбец "плотность населения" и оцените его как количество жителей, разделённое на площадь населенного пункта.
#
# 2. Постройте не менее 5 различных информативных графика при помощи библиотек matplotlib и/или seaborn.
#
# Важно:
# - графики и оси должны быть подписаны
# - графики должны быть легко читаемыми и понятными
#
# Попробуйте в графиках сравнивать не только деревни по отдельности, но и учтите сравнения между муниципальными образованиями.

# %%
# TODO

# %% [markdown]
# Какие выводы о Вашем районе можно сделать исходя  из графиков?

# %% [markdown]
# <font color="violet">TODO </font>

# %% [markdown]
# ## Часть 3. Предобработка данных. 3 балла.
#
# 0. Координаты нужно получить в десятичной записи для дальнейшей работы с ними.
#
# Нам нужно понять, в какие пункты нам НЕ нужно заезжать.
#
# 1. Удали из датасета города и поселки городского типа - в них точно есть свои магазины; данные о координатах города при этом все равно надо будет сохранить - это будет начальной и конечной точкой каждого маршрута.
#
# 2. При помощи 2GIS API (places) проверь, нет ли в каждом из оставшихся населённых пунктов своего магазина. Если есть - в него заезжать не надо.
#
# 3. Проверь по Яндекс Картам (просто открой карты и посмотри на свои населенные пункты визуально) - все ли правильно проработало в 2 пункте? Если были ошибки, предложи варианты, как улучшить данные.

# %%
# TODO

# %% [markdown]
# <font color="violet">TODO </font>

# %% [markdown]
# ## Часть 4. Поиск маршрутов. 5 баллов.
#
# Давай предположим, что на остановку в населенном пункте размером до 25 человек мы тратим 15 минут, а на остановку в населенном пункте большего размера мы тратим 30 минут.
#
# Выезжать из города мы не можем раньше 8 часов утра, возвращаться должны не позднее 20. У нас есть 5 рабочих дней у одной машины/бригады (пн-пт).
#
# Результатом работы алгоритма должно стать:
# - минимальное количество бригад, которое нам нужно, чтобы в каждый населенный пункт приехать хотя бы 1 раз на неделе.
# - их расписание, например:
#
# \\
#
# **Понедельник - бригада 1** \\
# 8:00 - выезд из города \\
# 8:45 - приезжаем в село А \\
# 9:00 - выезжаем из села А \\
# ...
#
# \\
# Для поиска расстояний между населенными пунктами здесь **нужно использовать Routing API от 2GIS**.
#
# Решение **не обязано быть самым оптимальным**, НО совсем топорные ошибки приведут к снижению баллов за задание (например, у нас 20 населенных пунктов и поэтому нужно 20 бригад, каждая бригада раз в неделю ездит в соответствующее село - это плохое решение)
#
# За лучшие решения с реализацией более продвинутых алгоритмов и/или использованием интересных оптимизаций **будут выдаваться дополнительные баллы за задание**.

# %%
# TODO

# %% [markdown]
# ## Часть 5-1. Рефлексия над построенным маршрутом: оплата. 1 балл.
#
# В одной бригаде у нас 2 человека (водитель и продавец).
#
# Поиграйте с формулами, надо, чтобы работа 2 человек оплачивалась после недели работы.
#
# **Нужно учесть:**
# - Зарплата работников не может быть ниже зарплатного минимума для области.
# - Не каждую неделю 100% жителей будут покупать продукты, но с другой стороны во всех этих селах есть дачники, которые не учитываются в жителях. Оцените (из головы), сколько процентов от жителей села будут в среднем покупать у вас продукты.
# - Пусть на все продукты одинаковая наценка. Какой должна быть наценка, чтобы все окупилось?
# - Каким должен быть средний чек, чтобы все это окупилось?

# %%
# TODO

# %% [markdown]
# <font color="violet">TODO </font>

# %% [markdown]
# ## Часть 5-2. Рефлексия над построенным маршрутом: оптимальность. 1 балл.
#
# Возьмите 2 дня из вашего графика и постройте оптимальный маршрут при помощи TSP 2GIS API. Совпали ли они? Чьё решение лучше - Ваше или 2GIS? Почему?

# %%
# TODO

# %% [markdown]
# <font color="violet">TODO </font>

# %% [markdown]
# ## Часть 6. Визуализация карт и маршрутов. 2 балла.
#
# При помощи plotly постройте 2 карты области:
#
# На 1 карте выведите населенные пункты, где цвет отвечает за Почтовый индекс деревни.
#
# На 2 карте выведите ваши маршруты, для каждой бригады свой цвет; Цвет населенного пункта должен отражать причастность к муниципальному образованию.

# %%
# TODO
